# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating a DataFrame

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns =columns)
df2

# %% [markdown]
# ### Selection and Indexing of Coulmns

# %%
df2

# %%
df2['Name']

# %%
df[['Name' , 'City']]

# %% [markdown]
# ### Creating a new Column

# %%
df2["Designation"] = ["Doctor","Eng","Doctor","Eng"]   ## no of vslues must match original df while adding new coulmn

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000         Eng
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000         Eng

# %% [markdown]
# ### Removing Columns

# %%
df2.drop('Designation' , axis = 1) ## default axis is 0 if not set
                                   ## original df not changed
                                   ##just a copy /snapshot of removed df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2.drop('Designation' , axis = 1) ## default axis is 0 if not set
#       2                                    ## original df not changed
#       3                                    ##just a copy /snapshot of removed df
#
# NameError: name 'df2' is not defined

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000         Eng
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000         Eng

# %%
df2.drop("City" , axis = 1 , inplace = True)

# %%
df2
# Out:
#     Name  Age  Salary
# 0   John   28   65000
# 1   Anna   34   70000
# 2  Peter   29   62000
# 3  Linda   42   85000

# %%
df2.drop(0 , axis = 0 , inplace = True)  ## removing rows

# %%
df2
# Out:
#     Name  Age  Salary
# 1   Anna   34   70000
# 2  Peter   29   62000
# 3  Linda   42   85000

# %% [markdown]
# ### Selecting A Rows

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns =columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df2.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %% [markdown]
# ### Selecting Subsets of Rows and Columns

# %%
df2.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2.loc[[2,3]][['Name','Age']]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# ### Conditional Selection

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#  age > 30

df2[df2['Age'] > 30 ]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
# age > 30 and their city paris

df2[(df2["Age"] > 30) & (df2["City"] == "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
